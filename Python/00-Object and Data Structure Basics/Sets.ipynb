# %%
myset = set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)
myset
# Out:
# {1}

# %%
myset.add(2)
myset
# Out:
# {1, 2}

# %%
myset.add(1)
myset
# Out:
# {1, 2}

# %%
mylist = [6, 3, 3, 4, 5, 4, 3, 2, 2, 1, 1, 2, 3, 4, 5, 6]

# %%
set(mylist)
# Out:
# {1, 2, 3, 4, 5, 6}
