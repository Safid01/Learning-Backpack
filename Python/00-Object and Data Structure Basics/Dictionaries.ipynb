# %%
my_dict = {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
my_dict
# Out:
# {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}

# %%
my_dict['key3']
# Out:
# 'value3'

# %%
prices_lookup = {'apple': 2.99, 'orange': 1.99, 'banana': 0.99}

# %%
prices_lookup['apple']
# Out:
# 2.99

# %%
d = {'k1': 100, 'k2': [1, 2, 3], 'k3': {'insidekey': 134}}

# %%
d['k2']
# Out:
# [1, 2, 3]

# %%
d['k3']
# Out:
# {'insidekey': 134}

# %%
d['k3']['insidekey']
# Out:
# 134

# %%
d2 = {'key1':['a', 'b', 'c']}

# %%
d
# Out:
# {'k1': 100, 'k2': [1, 2, 3], 'k3': {'insidekey': 134}}

# %%
d2
# Out:
# {'key1': ['a', 'b', 'c']}

# %%
mylist = d2['key1']

# %%
mylist
# Out:
# ['a', 'b', 'c']

# %%
letter = mylist[0]

# %%
print(letter.upper())
# Out:
# A

# %%
d2['key1'][2].upper()
# Out:
# 'C'

# %%
d2['key1'].append('d')

# %%
d2
# Out:
# {'key1': ['a', 'b', 'c', 'd']}

# %%
d2['key2'] = [1, 2, 3]

# %%
d2
# Out:
# {'key1': ['a', 'b', 'c', 'd'], 'key2': [1, 2, 3]}

# %%
d.values()
# Out:
# dict_values([100, [1, 2, 3], {'insidekey': 134}])

# %%
d.items()
# Out:
# dict_items([('k1', 100), ('k2', [1, 2, 3]), ('k3', {'insidekey': 134})])

# %%
d.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])
