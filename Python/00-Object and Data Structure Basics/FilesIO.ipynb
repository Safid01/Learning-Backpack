# %%
# %%writefile myfile.txt
# This is a simple text file.
# It contains some example text.
# Out:
# Overwriting myfile.txt

# %%
pwd
# Out:
# 'c:\\Users\\safid\\Downloads\\Learning-Backpack-1\\Python'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'This is a simple text file.\nIt contains some example text.\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)  # Reset the file pointer to the beginning
myfile.read()
# Out:
# 'This is a simple text file.\nIt contains some example text.\n'

# %%
myfile.seek(0)  # Reset the file pointer to the beginning
myfile.readline()
# Out:
# 'This is a simple text file.\n'

# %%
with open('myfile.txt', mode = 'r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'This is a simple text file.\nIt contains some example text.\n'

# %%
# %%writefile newfile.txt
# One is the loneliest number
# Two can be as bad as one
# Three is a magic number
# Out:
# Overwriting newfile.txt

# %%
with open('newfile.txt', mode = 'r') as f:
    print(f.read())
# Out:
# One is the loneliest number
# Two can be as bad as one
# Three is a magic number

# %%
with open('newfile.txt', mode = 'a') as f:
    f.write('Four is a magic number too')

# %%
with open('newfile.txt', mode = 'r') as f:
    print(f.read())
# Out:
# One is the loneliest number
# Two can be as bad as one
# Three is a magic number
# Four is a magic number too

# %%
with open('new_file.txt', mode = 'w') as f:
    f.write('This is a new file created with write mode.\n')
    f.write('It will overwrite any existing content.\n')
