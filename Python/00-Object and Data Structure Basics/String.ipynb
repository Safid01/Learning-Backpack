# %%
name = 'Safid'

# %%
first_letter = name[:2] +'bit'

# %%
first_letter
# Out:
# 'Sabit'

# %%
first_letter * 3
# Out:
# 'SabitSabitSabit'

# %%
name.upper()
# Out:
# 'SAFID'

# %%
name
# Out:
# 'Safid'

# %%
name.split('f')
# Out:
# ['Sa', 'id']

# %% [markdown]
# .format() method

# %%
print('This is a String {}'.format('inserteed'))
# Out:
# This is a String inserteed

# %%
print('The name is {0} and the first letter is {1}'.format('Safid', 'S'))
# Out:
# The name is Safid and the first letter is S

# %%
print('The first letter is {1} and the name is {0}'.format('Safid', 'S'))
# Out:
# The first letter is S and the name is Safid

# %%
print('The name is {n} and the first letter is {n}'.format(n='Safid', s='S'))
# Out:
# The name is Safid and the first letter is Safid

# %% [markdown]
# Float Formatting

# %%
result = 345/434

# %%
result
# Out:
# 0.7949308755760369

# %%
print("The result is {r:1.3f}".format(r=result))
# Out:
# The result is 0.795

# %%
name
# Out:
# 'Safid'

# %%
age = 21

# %%
print(f'{name} is {age} yeasrs old.')
# Out:
# Safid is 21 yeasrs old.
