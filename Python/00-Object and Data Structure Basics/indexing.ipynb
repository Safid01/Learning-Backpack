# %%
len('safid')
# Out:
# 5

# %%
len('Safid Hasan')
# Out:
# 11

# %%
mystring = "Safid Hasan"

# %%
mystring[6]
# Out:
# 'H'

# %%
mystring[-5]
# Out:
# 'H'

# %%
mystring[3:8]
# Out:
# 'id Ha'

# %%
mystring[:5]
# Out:
# 'Safid'

# %%
mystring[::3]
# Out:
# 'SiHa'

# %%
mystring[2:9:2]
# Out:
# 'fdHs'

# %%
mystring[::-1]
# Out:
# 'nasaH difaS'

# %%
print(mystring[6:12])
# Out:
# Hasan
