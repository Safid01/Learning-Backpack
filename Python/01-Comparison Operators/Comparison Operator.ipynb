# %%
2 == 1
# Out:
# False

# %%
'hello' == 'bye'
# Out:
# False

# %%
'Bye' == 'bye'
# Out:
# False

# %%
'Bye' == 'Bye'
# Out:
# True

# %%
'2' == 2
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
4 != 4
# Out:
# False

# %%
1 < 2
# Out:
# True

# %%
4 > 5
# Out:
# False

# %%
4 <= 5
# Out:
# True

# %%
5 >= 7
# Out:
# False
