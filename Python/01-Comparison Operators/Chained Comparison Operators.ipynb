# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
's' == 's' and 's' != 'S'
# Out:
# True

# %%
100 == 1 or 2 == 2
# Out:
# True

# %%
(45 == 45) and (45 != 46)
# Out:
# True

# %%
1 < 3
# Out:
# True

# %%
not 1 < 3
# Out:
# False
