# %%
import heapq

# %%
EX1 = {
    'S': {'A': 1,'B': 2,'C': 1},
    'A':{'C':1,'D':2,'G':6},
    'B': {'D':2,'E':3},
    'C':{'G':8},
    'D':{'E':1},
    'E':{'G':1},
    'G':{}
}

# %%
h1 = {
    'S':10,
    'A':8,
    'B':5,
    'C':5,
    'D':4,
    'E':2,
    'G':0
    }

# %%
EX2 = {
    'A': {'B': 1, 'C': 4},
    'B': {'D': 2, 'E': 5},
    'C': {'F': 3},
    'D': {},
    'E': {'F': 1},
    'F': {}
}

# %%
h2 = {
    'A': 7,
    'B': 6,
    'C': 2,
    'D': 1,
    'E': 1,
    'F': 0
}

# %%
def astar(graph, start, goal, heuristic):

    # Priority queue
    open_list = []
    heapq.heappush(open_list, (0, start))

    # Cost from start
    g_cost = {node: float('inf') for node in graph}
    g_cost[start] = 0

    # Parent tracking
    parent = {start: None}

    while open_list:

        current = heapq.heappop(open_list)[1]

        if current == goal:
            path = []
            while current:
                path.append(current)
                current = parent[current]
            return path[::-1]

        for neighbor, cost in graph[current].items():

            new_cost = g_cost[current] + cost

            if new_cost < g_cost[neighbor]:
                g_cost[neighbor] = new_cost
                f_cost = new_cost + heuristic[neighbor]

                heapq.heappush(open_list, (f_cost, neighbor))
                parent[neighbor] = current

    return None

# %%
path = astar(EX1, S, G, h1)

print("Shortest Path:", path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_11971/1281234683.py in <cell line: 0>()
# ----> 1 path = astar(EX1, S, G, h1)
#       2
#       3 print("Shortest Path:", path)
#
# NameError: name 'EX1' is not defined
